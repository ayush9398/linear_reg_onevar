# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
data = pd.read_csv('ex1data1.txt',header=None)
X=data.iloc[:,0]
y=data.iloc[:,1]
m=len(y)
data.head()
# Out:
#         0        1
# 0  6.1101  17.5920
# 1  5.5277   9.1302
# 2  8.5186  13.6620
# 3  7.0032  11.8540
# 4  5.8598   6.8233

# %%
X=X[:,np.newaxis]
y=y[:,np.newaxis]
theta=np.random.rand(2,1)
alpha=0.01
iters=100
ones=np.ones((m,1))
X=np.hstack((ones,X))
print(X[1:5,:])
# Out:
# [[1.     5.5277]
#  [1.     8.5186]
#  [1.     7.0032]
#  [1.     5.8598]]

# %%
plt.scatter(X[:,1],y)
plt.xlabel("Population of City in 10000s")
plt.ylabel("Profit in $10000s")
plt.show()

# %%
def Jcost(X,y,theta):
    cost=X.dot(theta)-y
    cost=np.sum(np.power(cost,2))/(2*m)
    return cost
J=Jcost(X,y,theta)
print(J)
# Out:
# 4.482333953012045

# %%
def grad_desc(X,y,theta,alpha,iters):
    for i in range(iters):
        delta=X.dot(theta)-y
        delta=np.dot(X.T,delta)
        theta=theta-(alpha*delta/m)
        if i%100==0:
            plt.scatter(X[:,1],y)
            plt.xlabel("Population of City in 10000s")
            plt.ylabel("Profit in $10000s")
            plt.plot(X[:,1],np.dot(X,theta))
            plt.show()
            J=Jcost(X,y,theta)
            print("J=",J," Theta=",theta)
            time.sleep(5)
    return theta

theta=grad_desc(X,y,theta,alpha,iters)
print(theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-90de29aa2cd4> in <module>()
#      15     return theta
#      16
# ---> 17 theta=grad_desc(X,y,theta,alpha,iters)
#      18 print(theta)
#
# <ipython-input-61-90de29aa2cd4> in grad_desc(X, y, theta, alpha, iters)
#       1 def grad_desc(X,y,theta,alpha,iters):
#       2     for i in range(iters):
# ----> 3         delta=X.dot(theta)-y
#       4         delta=np.dot(X.T,delta)
#       5         theta=theta-(alpha*delta/m)
#
# ValueError: shapes (97,1) and (2,1) not aligned: 1 (dim 1) != 2 (dim 0)

# %%
plt.scatter(X[:,1],y)
plt.xlabel("Population of City in 10000s")
plt.ylabel("Profit in $10000s")
plt.plot(X[:,1],np.dot(X,theta))
plt.show()

# %%
def model(X,y,theta,alpha,iters):
    ones=np.ones((m,1))
    X=np.hstack((ones,X))
    J=Jcost(X,y,theta)
    plt.scatter(X[:,1],y)
    plt.xlabel("Population of City in 10000s")
    plt.ylabel("Profit in $10000s")
    plt.plot(X[:,1],np.dot(X,theta))
    plt.show()
    time.sleep(10)
    theta=grad_desc(X,y,theta,alpha,iters)
    J=Jcost(X,y,theta)
    return J,theta
    
data = pd.read_csv('ex1data1.txt',header=None)
X=data.iloc[:,0]
y=data.iloc[:,1]
X=X[:,np.newaxis]
y=y[:,np.newaxis]
m=len(y)
theta=np.random.rand(2,1)
alpha=0.01
iters=1000
model(X,y,theta,alpha,iters)
# Out:
# J= 6.67696933135949  Theta= [[0.17652571]
#  [0.65460566]]
# J= 5.536070542278265  Theta= [[-0.48500186]
#  [ 0.8503839 ]]
# J= 5.2152560535782335  Theta= [[-1.04806145]
#  [ 0.90694934]]
# J= 4.991620317760357  Theta= [[-1.51816982]
#  [ 0.95417682]]
# J= 4.835726665520833  Theta= [[-1.91067157]
#  [ 0.99360788]]
# J= 4.727055165772825  Theta= [[-2.23837818]
#  [ 1.02652957]]
